# %%
import requests
from bs4 import BeautifulSoup

url = "https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo=936"

html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml') 

win_nums = soup.select("span.ball_645")
    
lotto_936_num = [win_num.get_text() for win_num in win_nums]
lotto_936_num
# Out:
# ['7', '11', '13', '17', '18', '29', '43']

# %%
import requests
from bs4 import BeautifulSoup

one_num = []
two_num = []
three_num = []
four_num = []
five_num = []
six_num = []
bonus_num = []

for i in range(1, 10):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")
    lotto_num = [soup_lotto.get_text() for soup_lotto in soup_lottos]

    one_num.append(int(lotto_num[0]))
    two_num.append(int(lotto_num[1]))
    three_num.append(int(lotto_num[2]))
    four_num.append(int(lotto_num[3]))
    five_num.append(int(lotto_num[4]))
    six_num.append(int(lotto_num[5]))
    bonus_num.append(int(lotto_num[6]))

print(one_num)
print(two_num)
print(three_num)
print(four_num)
print(five_num)
print(six_num)
print(bonus_num)
# Out:
# [10, 9, 11, 14, 16, 14, 2, 8, 2]
# [23, 13, 16, 27, 24, 15, 9, 19, 4]
# [29, 21, 19, 30, 29, 26, 16, 25, 16]
# [33, 25, 21, 31, 40, 27, 25, 34, 17]
# [37, 32, 27, 40, 41, 40, 26, 37, 36]
# [40, 42, 31, 42, 42, 42, 40, 39, 39]
# [16, 2, 30, 2, 3, 34, 42, 9, 14]

# %%
import requests
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo=1"

html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml') 

soup_lottos = soup.select("span.ball_645")
lotto_num = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    
print(lotto_num)
# Out:
# [10, 23, 29, 33, 37, 40, 16]

# %%
import requests
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

for i in range(1, 10):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[0:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
print(lotto_num)
# Out:
# [[10, 23, 29, 33, 37, 40], [9, 13, 21, 25, 32, 42], [11, 16, 19, 21, 27, 31], [14, 27, 30, 31, 40, 42], [16, 24, 29, 40, 41, 42], [14, 15, 26, 27, 40, 42], [2, 9, 16, 25, 26, 40], [8, 19, 25, 34, 37, 39], [2, 4, 16, 17, 36, 39]]

# %%
import requests
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo=1"

html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml') 

soup_lotto_dates = soup.select("p.desc")
lotto_date = [soup_lotto_date.get_text().replace(" 추첨)","").replace("(","") for soup_lotto_date in soup_lotto_dates]
    
print(lotto_date)
# Out:
# ['2002년 12월 07일']

# %%
import requests
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

for i in range(1, 10):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lotto_dates = soup.select("p.desc")
    lotto_date_list = [soup_lotto_date.get_text().replace(" 추첨)","").replace("(","") for soup_lotto_date in soup_lotto_dates]
    lotto_date.append(lotto_date_list)
    
print(lotto_date)
# Out:
# [['2002년 12월 07일'], ['2002년 12월 14일'], ['2002년 12월 21일'], ['2002년 12월 28일'], ['2003년 01월 04일'], ['2003년 01월 11일'], ['2003년 01월 18일'], ['2003년 01월 25일'], ['2003년 02월 01일']]

# %%
import requests
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

for i in range(1, 10):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[0:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
    soup_lotto_dates = soup.select("p.desc")
    lotto_date_list = [soup_lotto_date.get_text().replace(" 추첨)","").replace("(","") for soup_lotto_date in soup_lotto_dates]
    lotto_date.append(lotto_date_list)
    
print(lotto_num)
print(lotto_date)
# Out:
# [[10, 23, 29, 33, 37, 40], [9, 13, 21, 25, 32, 42], [11, 16, 19, 21, 27, 31], [14, 27, 30, 31, 40, 42], [16, 24, 29, 40, 41, 42], [14, 15, 26, 27, 40, 42], [2, 9, 16, 25, 26, 40], [8, 19, 25, 34, 37, 39], [2, 4, 16, 17, 36, 39]]
# [['2002년 12월 07일'], ['2002년 12월 14일'], ['2002년 12월 21일'], ['2002년 12월 28일'], ['2003년 01월 04일'], ['2003년 01월 11일'], ['2003년 01월 18일'], ['2003년 01월 25일'], ['2003년 02월 01일']]

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

for i in range(1, 937):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[0:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
data = np.array(lotto_num)
index_date = pd.date_range("2002-12-07", periods=936, freq="7d")
columns_list = ["no.1","no.2","no.3","no.4","no.5","no.6"]
df_lotto = pd.DataFrame(data, index=index_date, columns=columns_list)
df_lotto
# Out:
#             no.1  no.2  no.3  no.4  no.5  no.6
# 2002-12-07    10    23    29    33    37    40
# 2002-12-14     9    13    21    25    32    42
# 2002-12-21    11    16    19    21    27    31
# 2002-12-28    14    27    30    31    40    42
# 2003-01-04    16    24    29    40    41    42
# ...          ...   ...   ...   ...   ...   ...
# 2020-10-10     1     6    15    36    37    38
# 2020-10-17    23    27    29    31    36    45
# 2020-10-24     1     3    30    33    36    39
# 2020-10-31     4    10    20    32    38    44
# 2020-11-07     7    11    13    17    18    29
#
# [936 rows x 6 columns]

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

lotto_date = []
lotto_num = []

for i in tqdm(range(1, 937)):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
print(lotto_num)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 936/936 [08:43<00:00,  1.79it/s]
# [[10, 23, 29, 33, 37, 40], [9, 13, 21, 25, 32, 42], [11, 16, 19, 21, 27, 31], [14, 27, 30, 31, 40, 42], [16, 24, 29, 40, 41, 42], [14, 15, 26, 27, 40, 42], [2, 9, 16, 25, 26, 40], [8, 19, 25, 34, 37, 39], [2, 4, 16, 17, 36, 39], [9, 25, 30, 33, 41, 44], [1, 7, 36, 37, 41, 42], [2, 11, 21, 25, 39, 45], [22, 23, 25, 37, 38, 42], [2, 6, 12, 31, 33, 40], [3, 4, 16, 30, 31, 37], [6, 7, 24, 37, 38, 40], [3, 4, 9, 17, 32, 37], [3, 12, 13, 19, 32, 35], [6, 30, 38, 39, 40, 43], [10, 14, 18, 20, 23, 30], [6, 12, 17, 18, 31, 32], [4, 5, 6, 8, 17, 39], [5, 13, 17, 18, 33, 42], [7, 8, 27, 29, 36, 43], [2, 4, 21, 26, 43, 44], [4, 5, 7, 18, 20, 25], [1, 20, 26, 28, 37, 43], [9, 18, 23, 25, 35, 37], [1, 5, 13, 34, 39, 40], [8, 17, 20, 35, 36, 44], [7, 9, 18, 23, 28, 35], [6, 14, 19, 25, 34, 44], [4, 7, 32, 33, 40, 41], [9, 26, 35, 37, 40, 42], [2, 3, 11, 26, 37, 43], [1, 10, 23, 26, 28, 40], [7, 27, 30, 33, 35, 37], [16, 17, 22, 30, 37, 43], [6, 7, 13, 15, 21, 43], [7, 13, 18, 19, 25, 26], [13, 20, 23, 35, 38, 43], [17, 18, 19, 21, 23, 32], [6, 31, 35, 38, 39, 44], [3, 11, 21, 30, 38, 45], [1, 10, 20, 27, 33, 35], [8, 13, 15, 23, 31, 38], [14, 17, 26, 31, 36, 45], [6, 10, 18, 26, 37, 38], [4, 7, 16, 19, 33, 40], [2, 10, 12, 15, 22, 44], [2, 3, 11, 16, 26, 44], [2, 4, 15, 16, 20, 29], [7, 8, 14, 32, 33, 39], [1, 8, 21, 27, 36, 39], [17, 21, 31, 37, 40, 44], [10, 14, 30, 31, 33, 37], [7, 10, 16, 25, 29, 44], [10, 24, 25, 33, 40, 44], [6, 29, 36, 39, 41, 45], [2, 8, 25, 36, 39, 42], [14, 15, 19, 30, 38, 43], [3, 8, 15, 27, 29, 35], [3, 20, 23, 36, 38, 40], [14, 15, 18, 21, 26, 36], [4, 25, 33, 36, 40, 43], [2, 3, 7, 17, 22, 24], [3, 7, 10, 15, 36, 38], [10, 12, 15, 16, 26, 39], [5, 8, 14, 15, 19, 39], [5, 19, 22, 25, 28, 43], [5, 9, 12, 16, 29, 41], [2, 4, 11, 17, 26, 27], [3, 12, 18, 32, 40, 43], [6, 15, 17, 18, 35, 40], [2, 5, 24, 32, 34, 44], [1, 3, 15, 22, 25, 37], [2, 18, 29, 32, 43, 44], [10, 13, 25, 29, 33, 35], [3, 12, 24, 27, 30, 32], [17, 18, 24, 25, 26, 30], [5, 7, 11, 13, 20, 33], [1, 2, 3, 14, 27, 42], [6, 10, 15, 17, 19, 34], [16, 23, 27, 34, 42, 45], [6, 8, 13, 23, 31, 36], [2, 12, 37, 39, 41, 45], [4, 12, 16, 23, 34, 43], [1, 17, 20, 24, 30, 41], [4, 26, 28, 29, 33, 40], [17, 20, 29, 35, 38, 44], [1, 21, 24, 26, 29, 42], [3, 14, 24, 33, 35, 36], [6, 22, 24, 36, 38, 44], [5, 32, 34, 40, 41, 45], [8, 17, 27, 31, 34, 43], [1, 3, 8, 21, 22, 31], [6, 7, 14, 15, 20, 36], [6, 9, 16, 23, 24, 32], [1, 3, 10, 27, 29, 37], [1, 7, 11, 23, 37, 42], [1, 3, 17, 32, 35, 45], [17, 22, 24, 26, 35, 40], [5, 14, 15, 27, 30, 45], [17, 32, 33, 34, 42, 44], [8, 10, 20, 34, 41, 45], [4, 10, 12, 22, 24, 33], [1, 4, 5, 6, 9, 31], [7, 18, 22, 23, 29, 44], [1, 5, 34, 36, 42, 44], [7, 20, 22, 23, 29, 43], [7, 18, 31, 33, 36, 40], [26, 29, 30, 33, 41, 42], [4, 9, 28, 33, 36, 45], [11, 14, 19, 26, 28, 41], [1, 2, 6, 9, 25, 28], [2, 4, 25, 31, 34, 37], [5, 10, 22, 34, 36, 44], [3, 4, 10, 17, 19, 22], [3, 11, 13, 14, 17, 21], [4, 6, 10, 11, 32, 37], [12, 28, 30, 34, 38, 43], [1, 11, 16, 17, 36, 40], [7, 17, 18, 28, 30, 45], [4, 16, 23, 25, 29, 42], [2, 8, 32, 33, 35, 36], [7, 20, 22, 27, 40, 43], [3, 5, 10, 29, 32, 43], [12, 30, 34, 36, 37, 45], [19, 23, 25, 28, 38, 42], [7, 19, 24, 27, 42, 45], [8, 10, 11, 14, 15, 21], [3, 17, 23, 34, 41, 45], [4, 7, 15, 18, 23, 26], [3, 12, 20, 23, 31, 35], [6, 14, 22, 28, 35, 39], [2, 16, 30, 36, 41, 42], [7, 9, 20, 25, 36, 39], [10, 11, 27, 28, 37, 39], [9, 11, 15, 20, 28, 43], [3, 13, 17, 18, 19, 28], [8, 12, 29, 31, 42, 43], [12, 16, 30, 34, 40, 44], [26, 27, 28, 42, 43, 45], [4, 15, 17, 26, 36, 37], [2, 3, 13, 20, 27, 44], [2, 19, 27, 35, 41, 42], [4, 6, 13, 21, 40, 42], [21, 25, 33, 34, 35, 36], [2, 11, 21, 34, 41, 42], [2, 18, 25, 28, 37, 39], [1, 2, 10, 13, 18, 19], [1, 5, 13, 26, 29, 34], [3, 8, 11, 12, 13, 36], [6, 19, 21, 35, 40, 45], [16, 19, 20, 32, 33, 41], [5, 18, 28, 30, 42, 45], [19, 26, 30, 33, 35, 39], [4, 9, 13, 18, 21, 34], [1, 18, 30, 41, 42, 43], [3, 7, 8, 34, 39, 41], [22, 34, 36, 40, 42, 45], [1, 5, 21 ...

# %%
import numpy as np

lotto_countlist = np.ravel(lotto_num, order='C').tolist()
lotto_countlist
# Out:
# [10,
#  23,
#  29,
#  33,
#  37,
#  40,
#  9,
#  13,
#  21,
#  25,
#  32,
#  42,
#  11,
#  16,
#  19,
#  21,
#  27,
#  31,
#  14,
#  27,
#  30,
#  31,
#  40,
#  42,
#  16,
#  24,
#  29,
#  40,
#  41,
#  42,
#  14,
#  15,
#  26,
#  27,
#  40,
#  42,
#  2,
#  9,
#  16,
#  25,
#  26,
#  40,
#  8,
#  19,
#  25,
#  34,
#  37,
#  39,
#  2,
#  4,
#  16,
#  17,
#  36,
#  39,
#  9,
#  25,
#  30,
#  33,
#  41,
#  44,
#  1,
#  7,
#  36,
#  37,
#  41,
#  42,
#  2,
#  11,
#  21,
#  25,
#  39,
#  45,
#  22,
#  23,
#  25,
#  37,
#  38,
#  42,
#  2,
#  6,
#  12,
#  31,
#  33,
#  40,
#  3,
#  4,
#  16,
#  30,
#  31,
#  37,
#  6,
#  7,
#  24,
#  37,
#  38,
#  40,
#  3,
#  4,
#  9,
#  17,
#  32,
#  37,
#  3,
#  12,
#  13,
#  19,
#  32,
#  35,
#  6,
#  30,
#  38,
#  39,
#  40,
#  43,
#  10,
#  14,
#  18,
#  20,
#  23,
#  30,
#  6,
#  12,
#  17,
#  18,
#  31,
#  32,
#  4,
#  5,
#  6,
#  8,
#  17,
#  39,
#  5,
#  13,
#  17,
#  18,
#  33,
#  42,
#  7,
#  8,
#  27,
#  29,
#  36,
#  43,
#  2,
#  4,
#  21,
#  26,
#  43,
#  44,
#  4,
#  5,
#  7,
#  18,
#  20,
#  25,
#  1,
#  20,
#  26,
#  28,
#  37,
#  43,
#  9,
#  18,
#  23,
#  25,
#  35,
#  37,
#  1,
#  5,
#  13,
#  34,
#  39,
#  40,
#  8,
#  17,
#  20,
#  35,
#  36,
#  44,
#  7,
#  9,
#  18,
#  23,
#  28,
#  35,
#  6,
#  14,
#  19,
#  25,
#  34,
#  44,
#  4,
#  7,
#  32,
#  33,
#  40,
#  41,
#  9,
#  26,
#  35,
#  37,
#  40,
#  42,
#  2,
#  3,
#  11,
#  26,
#  37,
#  43,
#  1,
#  10,
#  23,
#  26,
#  28,
#  40,
#  7,
#  27,
#  30,
#  33,
#  35,
#  37,
#  16,
#  17,
#  22,
#  30,
#  37,
#  43,
#  6,
#  7,
#  13,
#  15,
#  21,
#  43,
#  7,
#  13,
#  18,
#  19,
#  25,
#  26,
#  13,
#  20,
#  23,
#  35,
#  38,
#  43,
#  17,
#  18,
#  19,
#  21,
#  23,
#  32,
#  6,
#  31,
#  35,
#  38,
#  39,
#  44,
#  3,
#  11,
#  21,
#  30,
#  38,
#  45,
#  1,
#  10,
#  20,
#  27,
#  33,
#  35,
#  8,
#  13,
#  15,
#  23,
#  31,
#  38,
#  14,
#  17,
#  26,
#  31,
#  36,
#  45,
#  6,
#  10,
#  18,
#  26,
#  37,
#  38,
#  4,
#  7,
#  16,
#  19,
#  33,
#  40,
#  2,
#  10,
#  12,
#  15,
#  22,
#  44,
#  2,
#  3,
#  11,
#  16,
#  26,
#  44,
#  2,
#  4,
#  15,
#  16,
#  20,
#  29,
#  7,
#  8,
#  14,
#  32,
#  33,
#  39,
#  1,
#  8,
#  21,
#  27,
#  36,
#  39,
#  17,
#  21,
#  31,
#  37,
#  40,
#  44,
#  10,
#  14,
#  30,
#  31,
#  33,
#  37,
#  7,
#  10,
#  16,
#  25,
#  29,
#  44,
#  10,
#  24,
#  25,
#  33,
#  40,
#  44,
#  6,
#  29,
#  36,
#  39,
#  41,
#  45,
#  2,
#  8,
#  25,
#  36,
#  39,
#  42,
#  14,
#  15,
#  19,
#  30,
#  38,
#  43,
#  3,
#  8,
#  15,
#  27,
#  29,
#  35,
#  3,
#  20,
#  23,
#  36,
#  38,
#  40,
#  14,
#  15,
#  18,
#  21,
#  26,
#  36,
#  4,
#  25,
#  33,
#  36,
#  40,
#  43,
#  2,
#  3,
#  7,
#  17,
#  22,
#  24,
#  3,
#  7,
#  10,
#  15,
#  36,
#  38,
#  10,
#  12,
#  15,
#  16,
#  26,
#  39,
#  5,
#  8,
#  14,
#  15,
#  19,
#  39,
#  5,
#  19,
#  22,
#  25,
#  28,
#  43,
#  5,
#  9,
#  12,
#  16,
#  29,
#  41,
#  2,
#  4,
#  11,
#  17,
#  26,
#  27,
#  3,
#  12,
#  18,
#  32,
#  40,
#  43,
#  6,
#  15,
#  17,
#  18,
#  35,
#  40,
#  2,
#  5,
#  24,
#  32,
#  34,
#  44,
#  1,
#  3,
#  15,
#  22,
#  25,
#  37,
#  2,
#  18,
#  29,
#  32,
#  43,
#  44,
#  10,
#  13,
#  25,
#  29,
#  33,
#  35,
#  3,
#  12,
#  24,
#  27,
#  30,
#  32,
#  17,
#  18,
#  24,
#  25,
#  26,
#  30,
#  5,
#  7,
#  11,
#  13,
#  20,
#  33,
#  1,
#  2,
#  3,
#  14,
#  27,
#  42,
#  6,
#  10,
#  15,
#  17,
#  19,
#  34,
#  16,
#  23,
#  27,
#  34,
#  42,
#  45,
#  6,
#  8,
#  13,
#  23,
#  31,
#  36,
#  2,
#  12,
#  37,
#  39,
#  41,
#  45,
#  4,
#  12,
#  16,
#  23,
#  34,
#  43,
#  1,
#  17,
#  20,
#  24,
#  30,
#  41,
#  4,
#  26,
#  28,
#  29,
#  33,
#  40,
#  17,
#  20,
#  29,
#  35,
#  38,
#  44,
#  1,
#  21,
#  24,
#  26,
#  29,
#  42,
#  3,
#  14,
#  24,
#  33,
#  35,
#  36,
#  6,
#  22,
#  24,
#  36,
#  38,
#  44,
#  5,
#  32,
#  34,
#  40,
#  41,
#  45,
#  8,
#  17,
#  27,
#  31,
#  34,
#  43,
#  1,
#  3,
#  8,
#  21,
#  22,
#  31,
#  6,
#  7,
#  14,
#  15,
#  20,
#  36,
#  6,
#  9,
#  16,
#  23,
#  24,
#  32,
#  1,
#  3,
#  10,
#  27,
#  29,
#  37,
#  1,
#  7,
#  11,
#  23,
#  37,
#  42,
#  1,
#  3,
#  17,
#  32,
#  35,
#  45,
#  17,
#  22,
#  24,
#  26,
#  35,
#  40,
#  5,
#  14,
#  15,
#  27,
#  30,
#  45,
#  17,
#  32,
#  33,
#  34,
#  42,
#  44,
#  8,
#  10,
#  20,
#  34,
#  41,
#  45,
#  4,
#  10,
#  12,
#  22,
#  24,
#  33,
#  1,
#  4,
#  5,
#  6,
#  9,
#  31,
#  7,
#  18,
#  22,
#  23,
#  29,
#  44,
#  1,
#  5,
#  34,
#  36,
#  42,
#  44,
#  7,
#  20,
#  22,
#  23,
#  29,
#  43,
#  7,
#  18,
#  31,
#  33,
#  36,
#  40,
#  26,
#  29,
#  30,
#  33,
#  41,
#  42,
#  4,
#  9,
#  28,
#  33,
#  36,
#  45,
#  11,
#  14,
#  19,
#  26,
#  28,
#  41,
#  1,
#  2,
#  6,
#  9,
#  25,
#  28,
#  2,
#  4,
#  25,
#  31,
#  34,
#  37,
#  5,
#  10,
#  22,
#  34,
#  36,
#  44,
#  3,
#  4,
#  10,
#  17,
#  19,
#  22,
#  3,
#  11,
#  13,
#  14,
#  17,
#  21,
#  4,
#  6,
#  10,
#  11,
#  32,
#  37,
#  12,
#  28,
#  30,
#  34,
#  38,
#  43,
#  1,
#  11,
#  16,
#  17,
#  36,
#  40,
#  7,
#  17,
#  18,
#  28,
#  30,
#  45,
#  4,
#  16,
#  23,
#  25,
#  29,
#  42,
#  2,
#  8,
#  32,
#  33,
#  35,
#  36,
#  7,
#  20,
#  22,
#  27,
#  40,
#  43,
#  3,
#  5,
#  10,
#  29,
#  32,
#  43,
#  12,
#  30,
#  34,
#  36,
#  37,
#  45,
#  19,
#  23,
#  25,
#  28,
#  38,
#  42,
#  7,
#  19,
#  24,
#  27,
#  42,
#  45,
#  8,
#  10,
#  11,
#  14,
#  15,
#  21,
#  3,
#  17,
#  23,
#  34,
#  41,
#  45,
#  4,
#  7,
#  15,
#  18,
#  23,
#  26,
#  3,
#  12,
#  20,
#  23,
#  31,
#  35,
#  6,
#  14,
#  22,
#  28,
#  35,
#  39,
#  2,
#  16,
#  30,
#  36,
#  41,
#  42,
#  7,
#  9,
#  20,
#  25,
#  36,
#  39,
#  10,
#  11,
#  27,
#  28,
#  37,
#  39,
#  9,
#  11,
#  15,
#  20,
#  28,
#  43,
#  3,
#  13,
#  17,
#  18,
#  19,
#  28,
#  8,
#  12,
#  29,
#  31,
#  42,
#  43,
#  12,
#  16,
#  30,
#  34,
#  40,
#  44,
#  26,
#  27,
#  28,
#  42,
#  43,
#  45,
#  4,
#  15,
#  17,
#  26,
#  36,
#  37,
#  2,
#  3,
#  13,
#  20,
#  27,
#  44,
#  2,
#  19,
#  27,
#  35,
#  41,
#  42,
#  4,
#  6,
#  13,
#  21,
#  40,
#  42,
#  21,
#  25,
#  33,
#  34,
#  35,
#  36,
#  2,
#  11,
#  21,
#  34,
#  41,
#  42,
#  2,
#  18,
#  25,
#  28,
#  37,
#  39,
#  1,
#  2,
#  10,
#  13,
#  18,
#  19,
#  1,
#  5,
#  13,
#  26,
#  29,
#  34,
#  3,
#  8,
#  11,
#  12,
#  13,
#  36,
#  6,
#  19,
#  21,
#  35,
#  40,
#  45,
#  16,
#  19,
#  20,
#  32,
#  33,
#  41,
#  5,
#  18,
#  28,
#  30,
#  42,
#  45,
#  19,
#  26,
#  30,
#  33,
#  35,
#  39,
#  4,
#  9,
#  13,
#  18,
#  21,
#  34,
#  1,
#  18,
#  30,
#  41,
#  42,
#  43,
#  3,
#  7,
#  8,
#  34,
#  39,
#  41,
#  22,
#  34,
#  36,
#  40,
#  42,
#  45,
#  1,
#  5,
#  21,
#  25,
#  38,
#  41,
#  7,
#  11,
#  26,
#  28,
#  29,
#  44,
#  6,
#  9,
#  10,
#  11,
#  39,
#  41,
#  5,
#  13,
#  18,
#  19,
#  22,
#  42,
#  9,
#  12,
#  27,
#  36,
#  39,
#  45,
#  24,
#  27,
#  28,
#  30,
#  ...]

# %%
lotto_count_value = []

for i in range(1,46):
    lotto_count_value.append(lotto_countlist.count(i))
    
lotto_count_value
# Out:
# [131,
#  122,
#  125,
#  127,
#  128,
#  118,
#  125,
#  125,
#  95,
#  128,
#  127,
#  133,
#  131,
#  132,
#  126,
#  121,
#  136,
#  136,
#  129,
#  131,
#  125,
#  105,
#  113,
#  123,
#  121,
#  125,
#  138,
#  116,
#  113,
#  112,
#  126,
#  109,
#  130,
#  146,
#  114,
#  124,
#  128,
#  127,
#  134,
#  132,
#  113,
#  121,
#  139,
#  125,
#  131]

# %%
lotto_count_value = []

for i in range(1,46):
    lotto_count_value.append(lotto_countlist.count(i))
    
data = np.array(lotto_count_value)
index_num = [i for i in range(1,46)] 
columns_list = ["count"]
df_lotto_count = pd.DataFrame(data, index=index_num, columns=columns_list)
df_lotto_count
# Out:
#     count
# 1     131
# 2     122
# 3     125
# 4     127
# 5     128
# 6     118
# 7     125
# 8     125
# 9      95
# 10    128
# 11    127
# 12    133
# 13    131
# 14    132
# 15    126
# 16    121
# 17    136
# 18    136
# 19    129
# 20    131
# 21    125
# 22    105
# 23    113
# 24    123
# 25    121
# 26    125
# 27    138
# 28    116
# 29    113
# 30    112
# 31    126
# 32    109
# 33    130
# 34    146
# 35    114
# 36    124
# 37    128
# 38    127
# 39    134
# 40    132
# 41    113
# 42    121
# 43    139
# 44    125
# 45    131

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import numpy as np

lotto_num = [] # 역대 로또 번호를 저장하는 리스트

# 로또 사이트에서 역대 로또 당첨 번호를 크롤링해서 lotto_num 리스트에 추가하기
for i in tqdm(range(1, 937)):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
# 다차원 배열을 1차원 배열로 만들기 (개수를 세기 위해서)
lotto_countlist = np.ravel(lotto_num, order='C').tolist()

# 1~45까지 카운트한 횟수를 넣는 리스트
lotto_count_value = []

for i in range(1,46):
    lotto_count_value.append(lotto_countlist.count(i))
    
# 카운트한 값을 데이터프레임으로 만들기
data = np.array(lotto_count_value)
index_num = [i for i in range(1,46)] 
columns_list = ["count"]
df_lotto_count = pd.DataFrame(data, index=index_num, columns=columns_list)
df_lotto_count
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 936/936 [11:16<00:00,  1.38it/s]
#     count
# 1     131
# 2     122
# 3     125
# 4     127
# 5     128
# 6     118
# 7     125
# 8     125
# 9      95
# 10    128
# 11    127
# 12    133
# 13    131
# 14    132
# 15    126
# 16    121
# 17    136
# 18    136
# 19    129
# 20    131
# 21    125
# 22    105
# 23    113
# 24    123
# 25    121
# 26    125
# 27    138
# 28    116
# 29    113
# 30    112
# 31    126
# 32    109
# 33    130
# 34    146
# 35    114
# 36    124
# 37    128
# 38    127
# 39    134
# 40    132
# 41    113
# 42    121
# 43    139
# 44    125
# 45    131

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['axes.unicode_minus'] = False


count_bar = df_lotto_count.plot.bar(width = 0.8, grid=True)
count_bar.set_xlabel("로또 번호")
count_bar.set_ylabel("횟수")
count_bar.set_title("역대 로또 번호 횟수")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['axes.unicode_minus'] = False


count_plt = df_lotto_count.plot()
plt.xlabel("로또 번호")
plt.ylabel("횟수")
plt.title("역대 로또 번호 횟수")
plt.show()

# %%
# 가장 많이 나온 로또 번호
top10 = df_lotto_count.nlargest(10, 'count')
print(top10)

top10_list = top10.index.tolist()
print(top10_list)
# Out:
#     count
# 34    146
# 43    139
# 27    138
# 17    136
# 18    136
# 39    134
# 12    133
# 14    132
# 40    132
# 1     131
# [34, 43, 27, 17, 18, 39, 12, 14, 40, 1]

# %% [markdown]
# ### Top10으로 로또 추첨기 만들기

# %%
import random

top10_lotto = random.sample(top10_list, 6)
print(top10_lotto)
# Out:
# [1, 18, 17, 14, 43, 40]

# %% [markdown]
# ### 역대 당첨번호와 비교하기

# %%
print(lotto_num) # 역대 로또 당첨 번호
print(top10_lotto) # TOP10을 기반으로 한 로또 번호
# Out:
# [[10, 23, 29, 33, 37, 40], [9, 13, 21, 25, 32, 42], [11, 16, 19, 21, 27, 31], [14, 27, 30, 31, 40, 42], [16, 24, 29, 40, 41, 42], [14, 15, 26, 27, 40, 42], [2, 9, 16, 25, 26, 40], [8, 19, 25, 34, 37, 39], [2, 4, 16, 17, 36, 39], [9, 25, 30, 33, 41, 44], [1, 7, 36, 37, 41, 42], [2, 11, 21, 25, 39, 45], [22, 23, 25, 37, 38, 42], [2, 6, 12, 31, 33, 40], [3, 4, 16, 30, 31, 37], [6, 7, 24, 37, 38, 40], [3, 4, 9, 17, 32, 37], [3, 12, 13, 19, 32, 35], [6, 30, 38, 39, 40, 43], [10, 14, 18, 20, 23, 30], [6, 12, 17, 18, 31, 32], [4, 5, 6, 8, 17, 39], [5, 13, 17, 18, 33, 42], [7, 8, 27, 29, 36, 43], [2, 4, 21, 26, 43, 44], [4, 5, 7, 18, 20, 25], [1, 20, 26, 28, 37, 43], [9, 18, 23, 25, 35, 37], [1, 5, 13, 34, 39, 40], [8, 17, 20, 35, 36, 44], [7, 9, 18, 23, 28, 35], [6, 14, 19, 25, 34, 44], [4, 7, 32, 33, 40, 41], [9, 26, 35, 37, 40, 42], [2, 3, 11, 26, 37, 43], [1, 10, 23, 26, 28, 40], [7, 27, 30, 33, 35, 37], [16, 17, 22, 30, 37, 43], [6, 7, 13, 15, 21, 43], [7, 13, 18, 19, 25, 26], [13, 20, 23, 35, 38, 43], [17, 18, 19, 21, 23, 32], [6, 31, 35, 38, 39, 44], [3, 11, 21, 30, 38, 45], [1, 10, 20, 27, 33, 35], [8, 13, 15, 23, 31, 38], [14, 17, 26, 31, 36, 45], [6, 10, 18, 26, 37, 38], [4, 7, 16, 19, 33, 40], [2, 10, 12, 15, 22, 44], [2, 3, 11, 16, 26, 44], [2, 4, 15, 16, 20, 29], [7, 8, 14, 32, 33, 39], [1, 8, 21, 27, 36, 39], [17, 21, 31, 37, 40, 44], [10, 14, 30, 31, 33, 37], [7, 10, 16, 25, 29, 44], [10, 24, 25, 33, 40, 44], [6, 29, 36, 39, 41, 45], [2, 8, 25, 36, 39, 42], [14, 15, 19, 30, 38, 43], [3, 8, 15, 27, 29, 35], [3, 20, 23, 36, 38, 40], [14, 15, 18, 21, 26, 36], [4, 25, 33, 36, 40, 43], [2, 3, 7, 17, 22, 24], [3, 7, 10, 15, 36, 38], [10, 12, 15, 16, 26, 39], [5, 8, 14, 15, 19, 39], [5, 19, 22, 25, 28, 43], [5, 9, 12, 16, 29, 41], [2, 4, 11, 17, 26, 27], [3, 12, 18, 32, 40, 43], [6, 15, 17, 18, 35, 40], [2, 5, 24, 32, 34, 44], [1, 3, 15, 22, 25, 37], [2, 18, 29, 32, 43, 44], [10, 13, 25, 29, 33, 35], [3, 12, 24, 27, 30, 32], [17, 18, 24, 25, 26, 30], [5, 7, 11, 13, 20, 33], [1, 2, 3, 14, 27, 42], [6, 10, 15, 17, 19, 34], [16, 23, 27, 34, 42, 45], [6, 8, 13, 23, 31, 36], [2, 12, 37, 39, 41, 45], [4, 12, 16, 23, 34, 43], [1, 17, 20, 24, 30, 41], [4, 26, 28, 29, 33, 40], [17, 20, 29, 35, 38, 44], [1, 21, 24, 26, 29, 42], [3, 14, 24, 33, 35, 36], [6, 22, 24, 36, 38, 44], [5, 32, 34, 40, 41, 45], [8, 17, 27, 31, 34, 43], [1, 3, 8, 21, 22, 31], [6, 7, 14, 15, 20, 36], [6, 9, 16, 23, 24, 32], [1, 3, 10, 27, 29, 37], [1, 7, 11, 23, 37, 42], [1, 3, 17, 32, 35, 45], [17, 22, 24, 26, 35, 40], [5, 14, 15, 27, 30, 45], [17, 32, 33, 34, 42, 44], [8, 10, 20, 34, 41, 45], [4, 10, 12, 22, 24, 33], [1, 4, 5, 6, 9, 31], [7, 18, 22, 23, 29, 44], [1, 5, 34, 36, 42, 44], [7, 20, 22, 23, 29, 43], [7, 18, 31, 33, 36, 40], [26, 29, 30, 33, 41, 42], [4, 9, 28, 33, 36, 45], [11, 14, 19, 26, 28, 41], [1, 2, 6, 9, 25, 28], [2, 4, 25, 31, 34, 37], [5, 10, 22, 34, 36, 44], [3, 4, 10, 17, 19, 22], [3, 11, 13, 14, 17, 21], [4, 6, 10, 11, 32, 37], [12, 28, 30, 34, 38, 43], [1, 11, 16, 17, 36, 40], [7, 17, 18, 28, 30, 45], [4, 16, 23, 25, 29, 42], [2, 8, 32, 33, 35, 36], [7, 20, 22, 27, 40, 43], [3, 5, 10, 29, 32, 43], [12, 30, 34, 36, 37, 45], [19, 23, 25, 28, 38, 42], [7, 19, 24, 27, 42, 45], [8, 10, 11, 14, 15, 21], [3, 17, 23, 34, 41, 45], [4, 7, 15, 18, 23, 26], [3, 12, 20, 23, 31, 35], [6, 14, 22, 28, 35, 39], [2, 16, 30, 36, 41, 42], [7, 9, 20, 25, 36, 39], [10, 11, 27, 28, 37, 39], [9, 11, 15, 20, 28, 43], [3, 13, 17, 18, 19, 28], [8, 12, 29, 31, 42, 43], [12, 16, 30, 34, 40, 44], [26, 27, 28, 42, 43, 45], [4, 15, 17, 26, 36, 37], [2, 3, 13, 20, 27, 44], [2, 19, 27, 35, 41, 42], [4, 6, 13, 21, 40, 42], [21, 25, 33, 34, 35, 36], [2, 11, 21, 34, 41, 42], [2, 18, 25, 28, 37, 39], [1, 2, 10, 13, 18, 19], [1, 5, 13, 26, 29, 34], [3, 8, 11, 12, 13, 36], [6, 19, 21, 35, 40, 45], [16, 19, 20, 32, 33, 41], [5, 18, 28, 30, 42, 45], [19, 26, 30, 33, 35, 39], [4, 9, 13, 18, 21, 34], [1, 18, 30, 41, 42, 43], [3, 7, 8, 34, 39, 41], [22, 34, 36, 40, 42, 45], [1, 5, 21 ...
# [1, 18, 17, 14, 43, 40]

# %%
import random

# top10을 기반으로 로또 번호 추첨하기
top10_lotto = random.sample(top10_list, 6)

if top10_lotto in lotto_num == True:
    print("기존에 1등에 당첨된 적이 있는 번호입니다.")
else:
    print(f"추천 로또 번호 : {top10_lotto}")
# Out:
# 추천 로또 번호 : [17, 34, 18, 1, 43, 39]

# %%
import random

count = 0

# top10을 기반으로 로또 번호 추첨하기
top10_lotto = random.sample(top10_list, 6)

while True:
    if top10_lotto in lotto_num == True:
        break
    else:
        count = count + 1
        if count > 1000000:
            break

print(count)
# Out:
# 1000001

# %% [markdown]
# ---

# %% [markdown]
# ## 코드 정리하기

# %% [markdown]
# #### 역대 로또 번호 데이터프레임에 저장하기

# %%
import pandas as pd
import numpy as np
import requests
from tqdm import tqdm
from bs4 import BeautifulSoup

lotto_date = []
lotto_num = []

for i in tqdm(range(1, 937)):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[0:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
data = np.array(lotto_num)
index_date = pd.date_range("2002-12-07", periods=936, freq="7d")
columns_list = ["no.1","no.2","no.3","no.4","no.5","no.6"]
df_lotto = pd.DataFrame(data, index=index_date, columns=columns_list)
df_lotto
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 936/936 [08:28<00:00,  1.84it/s]
#             no.1  no.2  no.3  no.4  no.5  no.6
# 2002-12-07    10    23    29    33    37    40
# 2002-12-14     9    13    21    25    32    42
# 2002-12-21    11    16    19    21    27    31
# 2002-12-28    14    27    30    31    40    42
# 2003-01-04    16    24    29    40    41    42
# ...          ...   ...   ...   ...   ...   ...
# 2020-10-10     1     6    15    36    37    38
# 2020-10-17    23    27    29    31    36    45
# 2020-10-24     1     3    30    33    36    39
# 2020-10-31     4    10    20    32    38    44
# 2020-11-07     7    11    13    17    18    29
#
# [936 rows x 6 columns]

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import numpy as np
import pandas as pd
import random

lotto_num = [] # 역대 로또 번호를 저장하는 리스트

# 로또 사이트에서 역대 로또 당첨 번호를 크롤링해서 lotto_num 리스트에 추가하기
for i in tqdm(range(1, 937)):
    url = f"https://dhlottery.co.kr/gameResult.do?method=byWin&drwNo={i}"

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml') 

    soup_lottos = soup.select("span.ball_645")[:6]
    lotto_num_list = [int(soup_lotto.get_text()) for soup_lotto in soup_lottos]
    lotto_num.append(lotto_num_list)
    
# 다차원 배열을 1차원 배열로 만들기 (개수를 세기 위해서)
lotto_countlist = np.ravel(lotto_num, order='C').tolist()

# 1~45까지 카운트한 횟수를 넣는 리스트
lotto_count_value = []

for i in range(1,46):
    lotto_count_value.append(lotto_countlist.count(i))
    
# 카운트한 값을 데이터프레임으로 만들기
data = np.array(lotto_count_value)
index_num = [i for i in range(1,46)] 
columns_list = ["count"]
df_lotto_count = pd.DataFrame(data, index=index_num, columns=columns_list)
print(df_lotto_count)

# 가장 많이 나온 로또 번호
top10 = df_lotto_count.nlargest(10, 'count')
print(top10)

top10_list = top10.index.tolist()
print(top10_list)

# top10을 기반으로 로또 번호 추첨하기
top10_lotto = random.sample(top10_list, 6)

if top10_lotto in lotto_num == True:
    print("기존에 1등에 당첨된 적이 있는 번호입니다.")
else:
    print(f"추천 로또 번호 : {top10_lotto}")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 936/936 [08:00<00:00,  1.95it/s]
#     count
# 1     131
# 2     122
# 3     125
# 4     127
# 5     128
# 6     118
# 7     125
# 8     125
# 9      95
# 10    128
# 11    127
# 12    133
# 13    131
# 14    132
# 15    126
# 16    121
# 17    136
# 18    136
# 19    129
# 20    131
# 21    125
# 22    105
# 23    113
# 24    123
# 25    121
# 26    125
# 27    138
# 28    116
# 29    113
# 30    112
# 31    126
# 32    109
# 33    130
# 34    146
# 35    114
# 36    124
# 37    128
# 38    127
# 39    134
# 40    132
# 41    113
# 42    121
# 43    139
# 44    125
# 45    131
#     count
# 34    146
# 43    139
# 27    138
# 17    136
# 18    136
# 39    134
# 12    133
# 14    132
# 40    132
# 1     131
# [34, 43, 27, 17, 18, 39, 12, 14, 40, 1]
# 추천 로또 번호 : [12, 43, 14, 39, 34, 27]

# %% [markdown]
# #### 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['axes.unicode_minus'] = False


count_plt = df_lotto_count.plot()
plt.xlabel("로또 번호")
plt.ylabel("횟수")
plt.title("역대 로또 번호 횟수")
# ax = plt.subplot()
# ax.set_xticks([i for i in range(1,46)])
plt.show()
